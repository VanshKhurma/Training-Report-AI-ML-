# %%
import pandas as pd

# %%
a=pd.read_csv("ipl-matches.csv")

# %%
a
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
a.shape
# Out:
# (950, 20)

# %%
a["SuperOver"].value_counts()[1]
# Out:
# /var/folders/ts/tt2bqv856gnflcc57nhhdxgw0000gn/T/ipykernel_17141/3241789719.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   a["SuperOver"].value_counts()[1]
# 14

# %%
a.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
a[(a["WinningTeam"]=="Chennai Super Kings") & (a["City"]=="Kolkata")].shape[0]
# Out:
# 5

# %%
a[a["City"]=="Kolkata"]
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 2    1312198  Kolkata  2022-05-25     2022   Eliminator
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 207  1178422  Kolkata  2019-04-28     2019           47
# 211  1178418  Kolkata  2019-04-25     2019           43
# 219  1178410  Kolkata  2019-04-19     2019           35
# ..       ...      ...         ...      ...          ...
# 908   336025  Kolkata  2008-05-18  2007/08           41
# 915   336017  Kolkata  2008-05-13  2007/08           35
# 922   336010  Kolkata  2008-05-08  2007/08           29
# 934   335997  Kolkata  2008-04-29  2007/08           16
# 945   335986  Kolkata  2008-04-20  2007/08            4
#
#                            Team1                        Team2  \
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 207        Kolkata Knight Riders               Mumbai Indians
# ...

# %%
(a[(a["TossWinner"] == a["WinningTeam"])].shape[0]/a.shape[0])*100
# Out:
# 51.473684210526315

# %%
b=pd.read_csv("movies.csv")

# %%
b
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
b[b["imdb_rating"]>8]
# Out:
#                                 title_x     imdb_id  \
# 0              Uri: The Surgical Strike   tt8291224
# 11                            Gully Boy   tt2395469
# 37                    Article 15 (film)  tt10324144
# 40                      Super 30 (film)   tt7485048
# 41                 Family of Thakurganj   tt8897986
# 53                          Section 375   tt8144834
# 58                    Ghost (2019 film)   tt9378950
# 59                     Bala (2019 film)   tt9420648
# 62                       Saand Ki Aankh   tt8108206
# 64                          Ujda Chaman  tt11046300
# 84                            Mukkabaaz   tt7180544
# 143                             Tumbbad   tt8239946
# 146                           Andhadhun   tt8108198
# 192            Sachin: A Billion Dreams   tt4640206
# 207                          G Kutta Se   tt4307132
# 216      Yadvi – The Dignified Princess   tt4910010
# 219                    Raag Desh (film)   tt6080746
# ...

# %%
b[b["imdb_votes"]>10000]
# Out:
#                        title_x    imdb_id  \
# 0     Uri: The Surgical Strike  tt8291224
# 11                   Gully Boy  tt2395469
# 15           Badla (2019 film)  tt8130968
# 22               Kesari (film)  tt6264938
# 30       Student of the Year 2  tt7255568
# ...                        ...        ...
# 1567                    Lagaan  tt0169102
# 1568                    Lagaan  tt0169102
# 1571            Dil Chahta Hai  tt0292490
# 1581              Aśoka (film)  tt0249371
# 1607   Nayak (2001 Hindi film)  tt0291376
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 15    https://upload.wikimedia.org/wikipedia/en/0/0c...
# 22    https://upload.wikimedia.org/wikipedia/en/thum...
# 30    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1567  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
b[(b["imdb_rating"] > 8) & (b["imdb_votes"] > 10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
b[b["genres"]=="Action "]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date]
# Index: []

# %%
b[b["imdb_rating"]>7.5]
# Out:
#                        title_x    imdb_id  \
# 0     Uri: The Surgical Strike  tt8291224
# 11                   Gully Boy  tt2395469
# 15           Badla (2019 film)  tt8130968
# 17                Hamid (film)  tt7527082
# 27          The Tashkent Files  tt8108268
# ...                        ...        ...
# 1568                    Lagaan  tt0169102
# 1571            Dil Chahta Hai  tt0292490
# 1589               Chandni Bar  tt0267363
# 1607   Nayak (2001 Hindi film)  tt0291376
# 1628                  Humsafar  tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 15    https://upload.wikimedia.org/wikipedia/en/0/0c...
# 17    https://upload.wikimedia.org/wikipedia/en/thum...
# 27    https://upload.wikimedia.org/wikipedia/en/7/79...
# ...                                                 ...
# 1568  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
b[(b["genres"]=="Action ") & (b["imdb_rating"] > 7.5)]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date]
# Index: []
