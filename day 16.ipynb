# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = sns.load_dataset("tips")

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2 = sns.load_dataset("penguins")

# %%
df2
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.plot(df1["size"], df1["tip"])

# %%
plt.scatter(df1["size"], df1["tip"])

# %%
plt.plot(df1["total_bill"])

# %%
plt.scatter(range(len(df1["total_bill"])), df1["total_bill"])

# %%
plt.plot(df1["total_bill"])
plt.xlabel("tip")
plt.ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
plt.hist(df1["total_bill"],color='m',edgecolor='black')
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
df1.head
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df1.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df1.groupby("day")["tip"].mean()
# Out:
# /var/folders/ts/tt2bqv856gnflcc57nhhdxgw0000gn/T/ipykernel_44519/367638764.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1.groupby("day")["tip"].mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
plt.plot(df1.groupby("day")["tip"].mean())
# Out:
# /var/folders/ts/tt2bqv856gnflcc57nhhdxgw0000gn/T/ipykernel_44519/2069327551.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   plt.plot(df1.groupby("day")["tip"].mean())

# %%
a=df1.groupby("day")["tip"].mean()
# Out:
# /var/folders/ts/tt2bqv856gnflcc57nhhdxgw0000gn/T/ipykernel_44519/593528440.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   a=df1.groupby("day")["tip"].mean()

# %%
a.index
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
a.values
# Out:
# array([2.77145161, 2.73473684, 2.99310345, 3.25513158])

# %%
plt.bar(a.index,a.values)
plt.xlabel('day of the week')
plt.ylabel('average tip')
plt.title('average tip of day')
# Out:
# Text(0.5, 1.0, 'average tip of day')

# %%
plt.barh(a.index,a.values)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.boxplot(df1['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x3017b1d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x3017b21b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x30178d2b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x3017b25a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x3017b2870>],
#  'means': []}

# %%
plt.boxplot(df1['size'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x3013bd730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x30164da90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x3013bd490>],
#  'medians': [<matplotlib.lines.Line2D at 0x30164fd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x30164e960>],
#  'means': []}

# %%
species_count= df["species"].value_counts()

# %%
df["species"].value_counts().index
# Out:
# Index(['setosa', 'versicolor', 'virginica'], dtype='object', name='species')

# %%
df["species"].value_counts().values
# Out:
# array([50, 50, 50])

# %%
plt.pie(species_count, labels= species_count.index,autopct='%1.2f%%')
plt.show()

# %%
plt.pie(species_count, labels= species_count.values,autopct='%1.2f%%')
plt.show()
